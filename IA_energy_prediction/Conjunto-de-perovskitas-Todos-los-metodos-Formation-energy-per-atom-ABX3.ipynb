# %%
import pandas as pd
import numpy as np
import time
import scipy.optimize as opt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
# %matplotlib inline 
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn import ensemble
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV 

from sklearn.ensemble import AdaBoostRegressor
from sklearn import linear_model
from sklearn.tree import DecisionTreeRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVR


from sklearn.gaussian_process.kernels import ConstantKernel, RBF
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve 
from sklearn.utils import shuffle

# %%
df = pd.read_csv('DatasetPerovskitasJuan.csv') #Aqui lo que se hace es cargar los datos.
df = df[df['Nsites'] == 5]
df = shuffle(df, random_state=2)
x = df.drop('Unnamed: 0', axis = 1)
x = x.drop('ID', axis = 1)
x = x.drop('full_formula', axis = 1)
x = x.drop('Energy', axis = 1)
x = x.drop('Energy_per_atom', axis = 1)
x = x.drop('Formation_energy_per_atom', axis = 1)
x = x.drop('E_above_hull', axis = 1)
x = x.drop("Band_gap",axis = 1) #Aqui quitamos la columna que correponde a la energia de gap
y = np.asarray(df['Formation_energy_per_atom']) #Aqui definimos la cantidad que deseamos predecir, en este caso la energia de gap
x = (x-x.mean())/x.std()
y = (y-y.mean())/y.std()
x = x.fillna(0)

X_train, X_test, y_train, y_test = train_test_split( x, y, test_size=0.1, random_state=9)

# %%
plt.hist(y, bins = 500)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
abr1 = GridSearchCV (AdaBoostRegressor (),{
    'random_state':[0,1,2], 'n_estimators':[1000], 'learning_rate':[0.001], 'loss': ['exponential']}, cv=5)
abr1.fit(X_train, y_train)
model = abr1.best_estimator_

# %%
print('Primero vemos las metricas')
abr_score = model.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.7159
# Model| R2 sq on test set: 0.4865
# Model| MSE on test set: 0.2294
# Model| MAE on test set: 0.3773
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
BR = GridSearchCV (linear_model.BayesianRidge(),{'tol':[1e-3]}, cv=5)
BR.fit(X_train, y_train) #Entrenamos el modelo
model1 = BR.best_estimator_ #Nos quedamos con el mejor modelo

# %%
print('Primero vemos las metricas')
abr_score = model1.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model1.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model1.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.7468
# Model| R2 sq on test set: 0.5263
# Model| MSE on test set: 0.2117
# Model| MAE on test set: 0.3146
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dtr1 = GridSearchCV (DecisionTreeRegressor(),{
    'criterion':['friedman_mse'], 'random_state':[0,1,2], 'splitter':['best'], 'max_depth':[None]}, cv=5, verbose = 3)
dtr1.fit(X_train,y_train)
#Aqui lo que hacemos es quedarnos con el mejor metodo, el que da mejores resultados, lo llamamos en este caso: model1
model2 = dtr1.best_estimator_
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END criterion=friedman_mse, max_depth=None, random_state=0, splitter=best;, score=0.680 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, random_state=0, splitter=best;, score=0.515 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=None, random_state=0, splitter=best;, score=0.407 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=None, random_state=0, splitter=best;, score=0.706 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=None, random_state=0, splitter=best;, score=0.472 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=None, random_state=1, splitter=best;, score=0.607 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, random_state=1, splitter=best;, score=0.529 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=None, random_state=1, splitter=best;, score=0.466 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=None, random_state=1, splitter=best;, score=0.698 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=None, random_state=1, splitter=best;, score=0.516 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=None, random_state=2, splitter=best;, score=0.636 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, random_state=2, splitter=best;, score=0.546 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=None, random_state=2, splitter=best;, score=0.445 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=None, random_state=2, splitter=best;, score=0.741 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=None, random_state=2, splitter=best;, score=0.466 total time=   0.0s

# %%
print('Primero vemos las metricas')
abr_score = model2.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model2.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model2.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 1.0000
# Model| R2 sq on test set: 0.6227
# Model| MSE on test set: 0.1686
# Model| MAE on test set: 0.2657
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
kernel = 15*RBF(1.0)+10*RBF(2.0)+5*RBF(3.0) #Definimos que tipo de kernel usar, en este caso uno contante de 15 y 2 tipo RBF
gpr1 = make_pipeline(StandardScaler(), GaussianProcessRegressor(kernel = kernel))
gpr1.fit(X_train, y_train) #Entrenamos el modelo
model3 = gpr1
# Out:
# c:\Users\Cronos\anaconda3\envs\kenai\lib\site-packages\sklearn\gaussian_process\kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k1__k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\Cronos\anaconda3\envs\kenai\lib\site-packages\sklearn\gaussian_process\kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__k2__k2__length_scale is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\Cronos\anaconda3\envs\kenai\lib\site-packages\sklearn\gaussian_process\kernels.py:420: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__k1__constant_value is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(

# %%
print('Primero vemos las metricas')
abr_score = model3.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model3.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model3.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 1.0000
# Model| R2 sq on test set: -0.0037
# Model| MSE on test set: 0.4485
# Model| MAE on test set: 0.5297
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
gbr = GridSearchCV(GradientBoostingRegressor (),{'n_estimators': [100,10,3], 'max_depth': [8], 'min_samples_split': [2], 'learning_rate': [0.1],
    'loss': ['squared_error'], 'random_state':[0,1,2]}, cv=5, verbose = 3)
#loss = 'ls', este es least squares
gbr.fit(X_train, y_train) #Entrenamos el modelo
model4 = gbr.best_estimator_ #Nos quedamos con el mejor modelo
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=0;, score=0.765 total time=   0.2s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=0;, score=0.725 total time=   0.2s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=0;, score=0.542 total time=   0.2s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=0;, score=0.820 total time=   0.2s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=0;, score=0.645 total time=   0.2s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=1;, score=0.753 total time=   0.2s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=1;, score=0.729 total time=   0.2s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=1;, score=0.525 total time=   0.2s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=1;, score=0.823 total time=   0.2s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=1;, score=0.648 total time=   0.2s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=2;, score=0.751 total time=   0.2s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=2;, score=0.734 total time=   0.2s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=2;, score=0.534 total time=   0.2s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=2;, score=0.827 total time=   0.2s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=2;, score=0.648 total time=   0.2s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=0;, score=0.659 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=0;, score=0.614 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=0;, score=0.532 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=0;, score=0.657 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=0;, score=0.645 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=1;, score=0.653 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=1;, score=0.618 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=1;, score=0.524 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=1;, score=0.658 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=1;, score=0.654 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=2;, score=0.650 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=2;, score=0.620 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=2;, score=0.524 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=2;, score=0.674 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=2;, score=0.651 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=0;, score=0.333 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=0;, score=0.317 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=0;, score=0.308 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=0;, score=0.336 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=0;, score=0.374 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=1;, score=0.334 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=1;, score=0.316 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=1;, score=0.304 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=1;, score=0.344 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=1;, score=0.371 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=2;, score=0.332 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=2;, score=0.309 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=2;, score=0.289 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=2;, score=0.348 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=2;, score=0.374 total time=   0.0s

# %%
print('Primero vemos las metricas')
abr_score = model4.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model4.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model4.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D')
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
#plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 1.0000
# Model| R2 sq on test set: 0.8357
# Model| MSE on test set: 0.0734
# Model| MAE on test set: 0.1795
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dif1 = (abs(yt - yp) / yt)*100
plt.hist(x=dif1, bins=100, color='#F2AB6D')
plt.title('Histograma del procentaje de error')
plt.xlabel('Porcentaje de error')
plt.ylabel('Frecuencia')
plt.xlim(-100,100)
#plt.xticks(range(-100,101,10))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
krr = GridSearchCV (KernelRidge (),{ 'alpha':[0.001],'kernel':['linear']}, cv=5,verbose=3)
krr.fit(X_train, y_train) #Entrenamos el modelo
model5 = krr.best_estimator_ #Nos quedamos con el mejor modelo
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ........alpha=0.001, kernel=linear;, score=0.776 total time=   0.0s
# [CV 2/5] END ........alpha=0.001, kernel=linear;, score=0.784 total time=   0.0s
# [CV 3/5] END ........alpha=0.001, kernel=linear;, score=0.556 total time=   0.0s
# [CV 4/5] END ........alpha=0.001, kernel=linear;, score=0.801 total time=   0.0s
# [CV 5/5] END ........alpha=0.001, kernel=linear;, score=0.120 total time=   0.0s

# %%
print('Primero vemos las metricas')
abr_score = model5.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model5.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model5.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.7728
# Model| R2 sq on test set: 0.4970
# Model| MSE on test set: 0.2247
# Model| MAE on test set: 0.3446
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
knr1 = KNeighborsRegressor(n_neighbors = 4, weights = 'distance', algorithm = 'ball_tree')
knr1.fit(X_train, y_train)
model6 = knr1

# %%
print('Primero vemos las metricas')
abr_score = model6.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model6.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model6.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 1.0000
# Model| R2 sq on test set: 0.5766
# Model| MSE on test set: 0.1892
# Model| MAE on test set: 0.3274
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
par = GridSearchCV (PassiveAggressiveRegressor(),{'max_iter':[1000], 'random_state':[10], 'tol':[1e-10]},
                   cv=5,verbose = 3)
#loss = 'ls', este es least squares
par.fit(X_train, y_train) #Entrenamos el modelo
model7 = par.best_estimator_ #Nos quedamos con el mejor modelo
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END max_iter=1000, random_state=10, tol=1e-10;, score=-0.222 total time=   0.0s
# [CV 2/5] END max_iter=1000, random_state=10, tol=1e-10;, score=0.030 total time=   0.0s
# [CV 3/5] END max_iter=1000, random_state=10, tol=1e-10;, score=0.477 total time=   0.0s
# [CV 4/5] END max_iter=1000, random_state=10, tol=1e-10;, score=0.649 total time=   0.0s
# [CV 5/5] END max_iter=1000, random_state=10, tol=1e-10;, score=0.032 total time=   0.0s

# %%
print('Primero vemos las metricas')
abr_score = model7.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model7.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model7.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.1195
# Model| R2 sq on test set: -0.8921
# Model| MSE on test set: 0.8454
# Model| MAE on test set: 0.7439
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
grid1 = GridSearchCV (RandomForestRegressor(),{'max_depth':[100], 'random_state':[0,1,2], 'criterion':['squared_error']
                                             }, cv=5, refit=True, verbose=3)
grid1.fit(X_train,y_train)
#Aqui lo que hacemos es quedarnos con el mejor metodo, el que da mejores resultados, lo llamamos en este caso: model1
model8 = grid1.best_estimator_
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END criterion=squared_error, max_depth=100, random_state=0;, score=0.751 total time=   0.3s
# [CV 2/5] END criterion=squared_error, max_depth=100, random_state=0;, score=0.824 total time=   0.3s
# [CV 3/5] END criterion=squared_error, max_depth=100, random_state=0;, score=0.563 total time=   0.3s
# [CV 4/5] END criterion=squared_error, max_depth=100, random_state=0;, score=0.834 total time=   0.3s
# [CV 5/5] END criterion=squared_error, max_depth=100, random_state=0;, score=0.676 total time=   0.2s
# [CV 1/5] END criterion=squared_error, max_depth=100, random_state=1;, score=0.749 total time=   0.2s
# [CV 2/5] END criterion=squared_error, max_depth=100, random_state=1;, score=0.821 total time=   0.2s
# [CV 3/5] END criterion=squared_error, max_depth=100, random_state=1;, score=0.598 total time=   0.2s
# [CV 4/5] END criterion=squared_error, max_depth=100, random_state=1;, score=0.844 total time=   0.3s
# [CV 5/5] END criterion=squared_error, max_depth=100, random_state=1;, score=0.673 total time=   0.2s
# [CV 1/5] END criterion=squared_error, max_depth=100, random_state=2;, score=0.760 total time=   0.2s
# [CV 2/5] END criterion=squared_error, max_depth=100, random_state=2;, score=0.808 total time=   0.2s
# [CV 3/5] END criterion=squared_error, max_depth=100, random_state=2;, score=0.588 total time=   0.3s
# [CV 4/5] END criterion=squared_error, max_depth=100, random_state=2;, score=0.845 total time=   0.3s
# [CV 5/5] END criterion=squared_error, max_depth=100, random_state=2;, score=0.657 total time=   0.3s

# %%
print('Primero vemos las metricas')
abr_score = model8.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model8.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model8.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.9636
# Model| R2 sq on test set: 0.8075
# Model| MSE on test set: 0.0860
# Model| MAE on test set: 0.2166
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sgd = (make_pipeline(StandardScaler(),SGDRegressor(max_iter=1000,tol=1e-1500,alpha=0.0001,epsilon=0.0001)))
sgd.fit(X_train, y_train) #Entrenamos el modelo
model9 = sgd #Nos quedamos con el mejor modelo

# %%
print('Primero vemos las metricas')
abr_score = model9.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model9.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model9.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.7387
# Model| R2 sq on test set: 0.4938
# Model| MSE on test set: 0.2262
# Model| MAE on test set: 0.3296
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
steps1 = [('scaler', StandardScaler()), ('SVM', SVR())]
pipeline1 = Pipeline(steps1) 
grid1 = GridSearchCV(pipeline1, param_grid= {'SVM__C':[100], 'SVM__gamma':['auto'], 'SVM__kernel': ['rbf'],
                                           'SVM__epsilon':[0.001]},cv = 5, refit=True,verbose=3, n_jobs = -1)
grid1.fit(X_train,y_train)
#Aqui lo que hacemos es quedarnos con el mejor metodo, el que da mejores resultados, lo llamamos en este caso: model1
model10 = grid1.best_estimator_
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits

# %%
print('Primero vemos las metricas')
abr_score = model10.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model10.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model10.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.9300
# Model| R2 sq on test set: 0.7080
# Model| MSE on test set: 0.1305
# Model| MAE on test set: 0.2207
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>
