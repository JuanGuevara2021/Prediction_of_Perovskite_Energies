# %%
import pandas as pd
import numpy as np
import time
import scipy.optimize as opt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
# %matplotlib inline 
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn import ensemble
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV 

from sklearn.ensemble import AdaBoostRegressor
from sklearn import linear_model
from sklearn.tree import DecisionTreeRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVR


from sklearn.gaussian_process.kernels import ConstantKernel, RBF
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve 
from sklearn.utils import shuffle

# %%
df = pd.read_csv('DatasetPerovskitasJuan.csv') #Aqui lo que se hace es cargar los datos.
df = df[df['Nsites'] == 10]
df = shuffle(df, random_state=2)
x = df.drop('Unnamed: 0', axis = 1)
x = x.drop('ID', axis = 1)
x = x.drop('full_formula', axis = 1)
#x = x.drop('Energy', axis = 1)
x = x.drop('Energy_per_atom', axis = 1)
x = x.drop('Formation_energy_per_atom', axis = 1)
x = x.drop('E_above_hull', axis = 1)
x = x.drop("Band_gap",axis = 1) #Aqui quitamos la columna que correponde a la energia de gap
y = np.asarray(df['Formation_energy_per_atom']) #Aqui definimos la cantidad que deseamos predecir, en este caso la energia de gap
#x = (x-x.mean())/x.std()
#y = (y-y.mean())/y.std()
x = x.fillna(0)

X_train, X_test, y_train, y_test = train_test_split( x, y, test_size=0.1, random_state=9)

# %%
plt.hist(y, bins = 500)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
abr1 = GridSearchCV (AdaBoostRegressor (),{
    'random_state':[0,1,2], 'n_estimators':[1000], 'learning_rate':[0.001], 'loss': ['exponential']}, cv=5)
abr1.fit(X_train, y_train)
model = abr1.best_estimator_

# %%
print('Primero vemos las metricas')
abr_score = model.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.7593
# Model| R2 sq on test set: 0.7360
# Model| MSE on test set: 0.2478
# Model| MAE on test set: 0.3458
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
BR = GridSearchCV (linear_model.BayesianRidge(),{'tol':[1e-3]}, cv=5)
BR.fit(X_train, y_train) #Entrenamos el modelo
model1 = BR.best_estimator_ #Nos quedamos con el mejor modelo

# %%
print('Primero vemos las metricas')
abr_score = model1.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model1.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model1.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.8139
# Model| R2 sq on test set: 0.8214
# Model| MSE on test set: 0.1676
# Model| MAE on test set: 0.3151
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dtr1 = GridSearchCV (DecisionTreeRegressor(),{
    'criterion':['friedman_mse'], 'random_state':[0,1,2], 'splitter':['best'], 'max_depth':[None]}, cv=5, verbose = 3)
dtr1.fit(X_train,y_train)
#Aqui lo que hacemos es quedarnos con el mejor metodo, el que da mejores resultados, lo llamamos en este caso: model1
model2 = dtr1.best_estimator_
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END criterion=friedman_mse, max_depth=None, random_state=0, splitter=best;, score=0.849 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, random_state=0, splitter=best;, score=0.711 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=None, random_state=0, splitter=best;, score=0.777 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=None, random_state=0, splitter=best;, score=0.701 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=None, random_state=0, splitter=best;, score=0.830 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=None, random_state=1, splitter=best;, score=0.847 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, random_state=1, splitter=best;, score=0.697 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=None, random_state=1, splitter=best;, score=0.825 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=None, random_state=1, splitter=best;, score=0.733 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=None, random_state=1, splitter=best;, score=0.773 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=None, random_state=2, splitter=best;, score=0.844 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, random_state=2, splitter=best;, score=0.720 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=None, random_state=2, splitter=best;, score=0.798 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=None, random_state=2, splitter=best;, score=0.775 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=None, random_state=2, splitter=best;, score=0.753 total time=   0.0s

# %%
print('Primero vemos las metricas')
abr_score = model2.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model2.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model2.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 1.0000
# Model| R2 sq on test set: 0.9219
# Model| MSE on test set: 0.0733
# Model| MAE on test set: 0.1496
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
kernel = 15*RBF(1.0)+10*RBF(2.0)+5*RBF(3.0) #Definimos que tipo de kernel usar, en este caso uno contante de 15 y 2 tipo RBF
gpr1 = make_pipeline(StandardScaler(), GaussianProcessRegressor(kernel = kernel))
gpr1.fit(X_train, y_train) #Entrenamos el modelo
model3 = gpr1
# Out:
# c:\Users\Cronos\anaconda3\envs\kenai\lib\site-packages\sklearn\gaussian_process\_gpr.py:616: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)

# %%
print('Primero vemos las metricas')
abr_score = model3.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model3.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model3.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 1.0000
# Model| R2 sq on test set: 0.8090
# Model| MSE on test set: 0.1792
# Model| MAE on test set: 0.1829
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
gbr = GridSearchCV(GradientBoostingRegressor (),{'n_estimators': [100,10,3], 'max_depth': [8], 'min_samples_split': [2], 'learning_rate': [0.1],
    'loss': ['squared_error'], 'random_state':[0,1,2]}, cv=5, verbose = 3)
#loss = 'ls', este es least squares
gbr.fit(X_train, y_train) #Entrenamos el modelo
model4 = gbr.best_estimator_ #Nos quedamos con el mejor modelo
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=0;, score=0.864 total time=   0.7s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=0;, score=0.844 total time=   0.7s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=0;, score=0.885 total time=   0.7s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=0;, score=0.845 total time=   0.7s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=0;, score=0.823 total time=   0.7s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=1;, score=0.861 total time=   0.7s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=1;, score=0.846 total time=   0.7s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=1;, score=0.886 total time=   0.9s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=1;, score=0.838 total time=   0.7s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=1;, score=0.834 total time=   0.7s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=2;, score=0.863 total time=   0.8s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=2;, score=0.845 total time=   0.8s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=2;, score=0.883 total time=   0.8s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=2;, score=0.841 total time=   0.8s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=2;, score=0.839 total time=   0.8s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=0;, score=0.738 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=0;, score=0.719 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=0;, score=0.756 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=0;, score=0.710 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=0;, score=0.716 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=1;, score=0.734 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=1;, score=0.724 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=1;, score=0.757 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=1;, score=0.709 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=1;, score=0.725 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=2;, score=0.740 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=2;, score=0.723 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=2;, score=0.756 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=2;, score=0.709 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=2;, score=0.729 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=0;, score=0.378 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=0;, score=0.371 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=0;, score=0.403 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=0;, score=0.366 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=0;, score=0.375 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=1;, score=0.376 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=1;, score=0.375 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=1;, score=0.405 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=1;, score=0.366 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=1;, score=0.382 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=2;, score=0.380 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=2;, score=0.375 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=2;, score=0.406 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=2;, score=0.365 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=2;, score=0.388 total time=   0.0s

# %%
print('Primero vemos las metricas')
abr_score = model4.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model4.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model4.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D')
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
#plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.9999
# Model| R2 sq on test set: 0.9396
# Model| MSE on test set: 0.0567
# Model| MAE on test set: 0.1412
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dif1 = (abs(yt - yp) / yt)*100
plt.hist(x=dif1, bins=50, color='#F2AB6D')
plt.title('Histograma del procentaje de error')
plt.xlabel('Porcentaje de error')
plt.ylabel('Frecuencia')
plt.xlim(-100,100)
#plt.xticks(range(-100,101,10))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
krr = GridSearchCV (KernelRidge (),{ 'alpha':[0.001],'kernel':['linear']}, cv=5,verbose=3)
krr.fit(X_train, y_train) #Entrenamos el modelo
model5 = krr.best_estimator_ #Nos quedamos con el mejor modelo
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ........alpha=0.001, kernel=linear;, score=0.736 total time=   0.0s
# [CV 2/5] END ........alpha=0.001, kernel=linear;, score=0.801 total time=   0.0s
# [CV 3/5] END ........alpha=0.001, kernel=linear;, score=0.686 total time=   0.0s
# [CV 4/5] END ......alpha=0.001, kernel=linear;, score=-10.735 total time=   0.0s
# [CV 5/5] END ........alpha=0.001, kernel=linear;, score=0.778 total time=   0.0s

# %%
print('Primero vemos las metricas')
abr_score = model5.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model5.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model5.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.8238
# Model| R2 sq on test set: 0.8218
# Model| MSE on test set: 0.1672
# Model| MAE on test set: 0.2990
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
knr1 = KNeighborsRegressor(n_neighbors = 4, weights = 'distance', algorithm = 'ball_tree')
knr1.fit(X_train, y_train)
model6 = knr1

# %%
print('Primero vemos las metricas')
abr_score = model6.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model6.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model6.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 1.0000
# Model| R2 sq on test set: 0.8832
# Model| MSE on test set: 0.1096
# Model| MAE on test set: 0.2279
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
par = GridSearchCV (PassiveAggressiveRegressor(),{'max_iter':[1000], 'random_state':[10], 'tol':[1e-10]},
                   cv=5,verbose = 3)
#loss = 'ls', este es least squares
par.fit(X_train, y_train) #Entrenamos el modelo
model7 = par.best_estimator_ #Nos quedamos con el mejor modelo
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END max_iter=1000, random_state=10, tol=1e-10;, score=0.627 total time=   0.0s
# [CV 2/5] END max_iter=1000, random_state=10, tol=1e-10;, score=0.490 total time=   0.0s
# [CV 3/5] END max_iter=1000, random_state=10, tol=1e-10;, score=0.299 total time=   0.0s
# [CV 4/5] END max_iter=1000, random_state=10, tol=1e-10;, score=0.411 total time=   0.0s
# [CV 5/5] END max_iter=1000, random_state=10, tol=1e-10;, score=0.554 total time=   0.0s

# %%
print('Primero vemos las metricas')
abr_score = model7.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model7.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model7.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.3910
# Model| R2 sq on test set: 0.3169
# Model| MSE on test set: 0.6409
# Model| MAE on test set: 0.6825
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
grid1 = GridSearchCV (RandomForestRegressor(),{'max_depth':[100], 'random_state':[0,1,2], 'criterion':['squared_error']
                                             }, cv=5, refit=True, verbose=3)
grid1.fit(X_train,y_train)
#Aqui lo que hacemos es quedarnos con el mejor metodo, el que da mejores resultados, lo llamamos en este caso: model1
model8 = grid1.best_estimator_
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END criterion=squared_error, max_depth=100, random_state=0;, score=0.918 total time=   0.8s
# [CV 2/5] END criterion=squared_error, max_depth=100, random_state=0;, score=0.944 total time=   0.8s
# [CV 3/5] END criterion=squared_error, max_depth=100, random_state=0;, score=0.944 total time=   0.8s
# [CV 4/5] END criterion=squared_error, max_depth=100, random_state=0;, score=0.898 total time=   0.7s
# [CV 5/5] END criterion=squared_error, max_depth=100, random_state=0;, score=0.854 total time=   0.7s
# [CV 1/5] END criterion=squared_error, max_depth=100, random_state=1;, score=0.910 total time=   0.8s
# [CV 2/5] END criterion=squared_error, max_depth=100, random_state=1;, score=0.942 total time=   0.8s
# [CV 3/5] END criterion=squared_error, max_depth=100, random_state=1;, score=0.949 total time=   0.9s
# [CV 4/5] END criterion=squared_error, max_depth=100, random_state=1;, score=0.909 total time=   0.8s
# [CV 5/5] END criterion=squared_error, max_depth=100, random_state=1;, score=0.852 total time=   0.7s
# [CV 1/5] END criterion=squared_error, max_depth=100, random_state=2;, score=0.911 total time=   0.7s
# [CV 2/5] END criterion=squared_error, max_depth=100, random_state=2;, score=0.943 total time=   0.8s
# [CV 3/5] END criterion=squared_error, max_depth=100, random_state=2;, score=0.948 total time=   0.8s
# [CV 4/5] END criterion=squared_error, max_depth=100, random_state=2;, score=0.900 total time=   0.7s
# [CV 5/5] END criterion=squared_error, max_depth=100, random_state=2;, score=0.850 total time=   0.8s

# %%
print('Primero vemos las metricas')
abr_score = model8.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model8.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model8.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
#plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.9881
# Model| R2 sq on test set: 0.9648
# Model| MSE on test set: 0.0255
# Model| MAE on test set: 0.0907
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sgd = (make_pipeline(StandardScaler(),SGDRegressor(max_iter=1000,tol=1e-1500,alpha=0.0001,epsilon=0.0001)))
sgd.fit(X_train, y_train) #Entrenamos el modelo
model9 = sgd #Nos quedamos con el mejor modelo

# %%
print('Primero vemos las metricas')
abr_score = model9.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model9.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model9.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.7857
# Model| R2 sq on test set: 0.7851
# Model| MSE on test set: 0.2016
# Model| MAE on test set: 0.3509
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
steps1 = [('scaler', StandardScaler()), ('SVM', SVR())]
pipeline1 = Pipeline(steps1) 
grid1 = GridSearchCV(pipeline1, param_grid= {'SVM__C':[100], 'SVM__gamma':['auto'], 'SVM__kernel': ['rbf'],
                                           'SVM__epsilon':[0.001]},cv = 5, refit=True,verbose=3, n_jobs = -1)
grid1.fit(X_train,y_train)
#Aqui lo que hacemos es quedarnos con el mejor metodo, el que da mejores resultados, lo llamamos en este caso: model1
model10 = grid1.best_estimator_
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits

# %%
print('Primero vemos las metricas')
abr_score = model10.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model10.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model10.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.9764
# Model| R2 sq on test set: 0.7449
# Model| MSE on test set: 0.2394
# Model| MAE on test set: 0.1633
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>
