# %%
import pandas as pd
import numpy as np
import time
import scipy.optimize as opt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
# %matplotlib inline 
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn import ensemble
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV 

from sklearn.ensemble import AdaBoostRegressor
from sklearn import linear_model
from sklearn.tree import DecisionTreeRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVR


from sklearn.gaussian_process.kernels import ConstantKernel, RBF
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve 
from sklearn.utils import shuffle

# %%
df = pd.read_csv('DatasetPerovskitasJuan.csv') #Aqui lo que se hace es cargar los datos.
df = df[df['Nsites'] == 10]
df = shuffle(df, random_state=2)
x = df.drop('Unnamed: 0', axis = 1)
x = x.drop('ID', axis = 1)
x = x.drop('full_formula', axis = 1)
x = x.drop('Energy', axis = 1)
x = x.drop('Energy_per_atom', axis = 1)
x = x.drop('Formation_energy_per_atom', axis = 1)
x = x.drop('E_above_hull', axis = 1)
x = x.drop("Band_gap",axis = 1) #Aqui quitamos la columna que correponde a la energia de gap
y = np.asarray(df['Energy']) #Aqui definimos la cantidad que deseamos predecir, en este caso la energia de gap
y_mean = y.mean()
y_std = y.std()
x = (x-x.mean())/x.std()
y = (y-y.mean())/y.std()
x = x.fillna(0)

X_train, X_test, y_train, y_test = train_test_split( x, y, test_size=0.1, random_state=9)

# %%
y_hist = y*y_std + y_mean
plt.hist(y_hist, bins = 500)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(y, bins = 500)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
abr1 = GridSearchCV (AdaBoostRegressor (),{
    'random_state':[0,1,2], 'n_estimators':[1000], 'learning_rate':[0.001], 'loss': ['exponential']}, cv=5)
abr1.fit(X_train, y_train)
model = abr1.best_estimator_

# %%
print('Primero vemos las metricas')
abr_score = model.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.8193
# Model| R2 sq on test set: 0.7935
# Model| MSE on test set: 0.1983
# Model| MAE on test set: 0.3425
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
BR = GridSearchCV (linear_model.BayesianRidge(),{'tol':[1e-3]}, cv=5)
BR.fit(X_train, y_train) #Entrenamos el modelo
model1 = BR.best_estimator_ #Nos quedamos con el mejor modelo

# %%
print('Primero vemos las metricas')
abr_score = model1.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model1.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model1.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.8827
# Model| R2 sq on test set: 0.8561
# Model| MSE on test set: 0.1382
# Model| MAE on test set: 0.2867
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dtr1 = GridSearchCV (DecisionTreeRegressor(),{
    'criterion':['friedman_mse'], 'random_state':[0,1,2], 'splitter':['best'], 'max_depth':[None]}, cv=5, verbose = 3)
dtr1.fit(X_train,y_train)
#Aqui lo que hacemos es quedarnos con el mejor metodo, el que da mejores resultados, lo llamamos en este caso: model1
model2 = dtr1.best_estimator_
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END criterion=friedman_mse, max_depth=None, random_state=0, splitter=best;, score=0.929 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, random_state=0, splitter=best;, score=0.844 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=None, random_state=0, splitter=best;, score=0.817 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=None, random_state=0, splitter=best;, score=0.834 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=None, random_state=0, splitter=best;, score=0.893 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=None, random_state=1, splitter=best;, score=0.923 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, random_state=1, splitter=best;, score=0.857 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=None, random_state=1, splitter=best;, score=0.853 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=None, random_state=1, splitter=best;, score=0.854 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=None, random_state=1, splitter=best;, score=0.903 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=None, random_state=2, splitter=best;, score=0.929 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, random_state=2, splitter=best;, score=0.864 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=None, random_state=2, splitter=best;, score=0.838 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=None, random_state=2, splitter=best;, score=0.836 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=None, random_state=2, splitter=best;, score=0.882 total time=   0.0s

# %%
print('Primero vemos las metricas')
abr_score = model2.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model2.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model2.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 1.0000
# Model| R2 sq on test set: 0.8814
# Model| MSE on test set: 0.1139
# Model| MAE on test set: 0.1808
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
kernel = 15*RBF(1.0)+10*RBF(2.0)+5*RBF(3.0) #Definimos que tipo de kernel usar, en este caso uno contante de 15 y 2 tipo RBF
gpr1 = make_pipeline(StandardScaler(), GaussianProcessRegressor(kernel = kernel))
gpr1.fit(X_train, y_train) #Entrenamos el modelo
model3 = gpr1

# %%
print('Primero vemos las metricas')
abr_score = model3.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model3.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model3.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D')
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
#plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 1.0000
# Model| R2 sq on test set: 0.9701
# Model| MSE on test set: 0.0292
# Model| MAE on test set: 0.1057
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
for i in range(len(yt)):
    print(yt[i], yp[i], (abs(yt[i] - yp[i]) / yt[i])*100,i)
# Out:
# -0.397268697201084 -0.3783631062903503 -4.758892669855715 0
# 1.2118563050893325 1.2181005397878444 0.515261972255991 1
# 0.7256530598608282 0.6314293227965713 12.984681285892727 2
# -1.0058418022480413 -0.6312297165824517 -37.243638594890086 3
# -0.47145832499041107 -0.4416063429069865 -6.331838998501447 4
# 1.3547178241609865 1.2444256463004155 8.141339539020086 5
# -0.49111794535908804 -0.4745449619091029 -3.3745424305087384 6
# 0.8048541581400199 0.7834147990994821 2.6637570078637838 7
# -0.8954908748994096 -0.9714572429745869 -8.483209623292991 8
# 0.9628182270209856 0.9842833979382597 2.2294105278509866 9
# -0.82373825904104 -0.8147751581692506 -1.088100591834094 10
# 1.2271245001602278 1.9156799744396613 56.11129711692071 11
# 0.34311326489518024 0.3644019738956574 6.2045718363528755 12
# 1.336080423220453 1.5668382099643319 17.27124974914806 13
# -0.09796332126796434 -0.1091137453741775 -11.382243845850034 14
# -1.2788190194594171 -1.1878490152676466 -7.113594872105152 15
# -0.6075855653662113 -0.4997859897611101 -17.74228713615455 16
# -0.44676519041818147 -0.6368566919934708 -42.54841371982445 17
# 0.6637880966126339 1.0101573680498976 52.18069941368564 18
# 0.6052259188166699 0.13076018518361643 78.3948140490617 19
# -0.42880877479331225 -0.42880877479331225 -0.0 20
# 0.5135711216223573 0.6600473139893028 28.521111526721203 21
# 0.21540071745304226 0.20939029843464801 2.7903430821694126 22
# -0.4117140973873556 -0.5274258286141857 -28.1048747082285 23
# 2.0543885948399243 1.5307132850119824 25.490567419585293 24
# -0.3200046624353822 -0.4267645169847255 -33.36196845910051 25
# -0.4171430878258504 -0.31662843168759736 -24.09596588598301 26
# 1.1798844352108135 1.355383984145481 14.874299863385376 27
# 0.9626706532746536 1.1868027487126982 23.28232346915626 28
# -0.5810634300368454 -0.5530097038519879 -4.827997209027346 29
# 1.7936971843448961 1.8591851627658347 3.6510052528658252 30
# 1.3805542094270005 1.4003083450796607 1.4308844605862472 31
# 1.2957912297251122 1.1759900185284675 9.245409943240562 32
# 0.19388598806684387 0.13946859034627757 28.066699539837526 33
# -0.8970247587427769 -0.7710828029745853 -14.03996428646019 34
# -0.5626029133248929 -0.675272946768098 -20.026564167139366 35
# 1.241879700633976 1.0875053797666552 12.43069846366867 36
# 1.8233509146881244 1.8600942581951458 2.0151548015816934 37
# -0.43582464407890487 -0.43741913613891836 -0.3658563327421243 38
# -0.6853504922140745 -0.6420090783130536 -6.323977934414737 39
# 1.3631975510649654 1.139586163971945 16.40344694856072 40
# 0.5577893288145417 0.4460053936069805 20.040529539195976 41
# 1.3212019787922364 1.3115809792149231 0.7282005122417594 42
# -1.0689520328872921 -1.202227949178103 -12.467904282928954 43
# -0.6101541711246525 -0.501842997341476 -17.751443636537715 44
# 0.7468685680339973 1.3305104952411013 78.1451987922642 45
# -0.7093313434159293 -0.637049649210196 -10.190117055542206 46
# -0.4055706720474476 -0.4395620761562488 -8.381129714631966 47
# -1.2153482801630113 -1.2420609134335925 -2.197940599134123 48
# -0.15815842060863575 -0.187580127472182 -18.60268125486059 49
# -0.6327759347847834 -0.7820925319537473 -23.5970726699252 50
# 1.606404270588564 1.6917475003730393 5.3126869336077425 51
# -1.302409721269804 -1.2693620126424265 -2.537427975826004 52
# -0.3220616245722487 -0.3575597838585711 -11.02216364134345 53
# -1.0763082973118936 -1.0872433410323845 -1.0159769043685218 54
# -1.774680708911035 -1.7268419174378684 -2.695628077375172 55
# -0.4111186302877614 -0.40329721084728404 -1.902472635453857 56
# -1.3306050536062266 -1.4177571796140214 -6.549811739523588 57
# -0.760933137886802 -0.6308472971869836 -17.095567826245748 58
# -0.09179309903096025 -0.10785740510922537 -17.50055968025102 59
# 0.9033412559006416 0.8713728393302942 3.5389080661963743 60
# 1.0636461728157582 1.0169060078197185 4.394333960917276 61
# -0.31849409682866714 -0.31849409682866714 -0.0 62
# -1.3582298981306427 -1.3865919600149805 -2.0881635666666676 63
# -0.9225316747645972 -1.0001277910546111 -8.411214315195647 64
# -1.7414523155502826 -1.7254844009847954 -0.9169309100744153 65
# -0.39825354738504176 -0.4917575543585371 -23.478512015134225 66
# -1.0148005921843362 -0.9420163883215777 -7.172266593389742 67
# -1.1569591085801887 -1.0622535711673997 -8.185729012411759 68
# -0.5205045439814957 -0.48843956517035636 -6.1603648194624165 69
# -0.7335619030959228 -0.7786563609960602 -6.147328222719963 70
# -1.2427740664790674 -1.2421306713944527 -0.05177088112544612 71
# -0.7981782745704398 -0.924037640387092 -15.76832768148027 72
# 1.10526528833253 1.10526528833253 0.0 73
# 1.3219553571393403 1.3221927594423293 0.01795842058560088 74
# 0.4746622374217355 0.5825122480493641 22.72142212396059 75
# 1.3377981534951708 1.2976903469689394 2.9980461866720804 76
# 1.2411552829465646 1.0201701580693274 17.804792672888397 77
# -1.2887818252077776 -1.0015874125311095 -22.28417619331081 78
# 0.946630363126722 1.0225087742238 8.015632505854914 79
# 1.1435903993965146 1.120484720511611 2.0204505824022903 80
# 0.6446285049872582 0.6446285049872582 0.0 81
# 2.2780295950534364 1.9851220259022968 12.857935199225047 82
# 1.7575697441842313 2.226478461460775 26.679380367587395 83
# -0.9300920380225783 -0.987152326505818 -6.134907745748756 84
# 0.8441836513692248 0.8807327907138829 4.329524657979003 85
# 0.4798287612556012 0.4663307993063661 2.813078964652729 86
# -1.0353993405618793 -1.051114141869496 -1.517752686522745 87
# -0.11785526050888152 -0.12802294246571577 -8.627261874380242 88
# 0.5160950271523721 0.29820597307724306 42.21878580721131 89
# 0.18711426918376778 0.30538593421574545 63.20825533397523 90
# -1.2787314182647331 -1.6536196429369134 -29.317198226106928 91
# 0.3826714907038421 0.3479241242317026 9.080207780367743 92
# -0.10822438682890186 -0.1299418327159243 -20.067053760587992 93
# -0.9224232059205207 -0.9472494902048754 -2.691420177312164 94
# -0.0137662113533881 -0.01591256844906319 -15.591487305959717 95

# %%
for i in [20,62,73,81]:
    yt[i] = yp[i]

# %%
dif1 = (abs(yt - yp) / yt)*100
plt.hist(x=dif1, bins=50, color='#F2AB6D')
plt.title('Histograma del procentaje de error')
plt.xlabel('Porcentaje de error')
plt.ylabel('Frecuencia')
plt.xlim(-100,100)
#plt.xticks(range(-100,101,10))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
gbr = GridSearchCV(GradientBoostingRegressor (),{'n_estimators': [100,10,3], 'max_depth': [8], 'min_samples_split': [2], 'learning_rate': [0.1],
    'loss': ['squared_error'], 'random_state':[0,1,2]}, cv=5, verbose = 3)
#loss = 'ls', este es least squares
gbr.fit(X_train, y_train) #Entrenamos el modelo
model4 = gbr.best_estimator_ #Nos quedamos con el mejor modelo
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=0;, score=0.947 total time=   0.7s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=0;, score=0.921 total time=   0.7s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=0;, score=0.929 total time=   0.7s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=0;, score=0.903 total time=   0.7s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=0;, score=0.943 total time=   0.7s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=1;, score=0.946 total time=   0.7s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=1;, score=0.914 total time=   0.7s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=1;, score=0.925 total time=   0.7s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=1;, score=0.905 total time=   0.7s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=1;, score=0.947 total time=   0.7s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=2;, score=0.946 total time=   0.7s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=2;, score=0.915 total time=   0.7s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=2;, score=0.924 total time=   0.7s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=2;, score=0.905 total time=   0.7s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=2;, score=0.943 total time=   0.7s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=0;, score=0.815 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=0;, score=0.792 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=0;, score=0.806 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=0;, score=0.759 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=0;, score=0.806 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=1;, score=0.813 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=1;, score=0.790 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=1;, score=0.802 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=1;, score=0.761 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=1;, score=0.809 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=2;, score=0.813 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=2;, score=0.785 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=2;, score=0.802 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=2;, score=0.762 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=2;, score=0.807 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=0;, score=0.422 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=0;, score=0.421 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=0;, score=0.425 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=0;, score=0.388 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=0;, score=0.426 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=1;, score=0.421 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=1;, score=0.427 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=1;, score=0.425 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=1;, score=0.388 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=1;, score=0.428 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=2;, score=0.421 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=2;, score=0.418 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=2;, score=0.423 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=2;, score=0.390 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=2;, score=0.427 total time=   0.0s

# %%
print('Primero vemos las metricas')
abr_score = model4.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model4.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model4.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.9999
# Model| R2 sq on test set: 0.9161
# Model| MSE on test set: 0.0806
# Model| MAE on test set: 0.1541
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
krr = GridSearchCV (KernelRidge (),{ 'alpha':[0.001],'kernel':['linear']}, cv=5,verbose=3)
krr.fit(X_train, y_train) #Entrenamos el modelo
model5 = krr.best_estimator_ #Nos quedamos con el mejor modelo
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ........alpha=0.001, kernel=linear;, score=0.837 total time=   0.0s
# [CV 2/5] END ........alpha=0.001, kernel=linear;, score=0.901 total time=   0.0s
# [CV 3/5] END ........alpha=0.001, kernel=linear;, score=0.815 total time=   0.0s
# [CV 4/5] END ......alpha=0.001, kernel=linear;, score=-13.335 total time=   0.0s
# [CV 5/5] END ........alpha=0.001, kernel=linear;, score=0.844 total time=   0.0s

# %%
print('Primero vemos las metricas')
abr_score = model5.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model5.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model5.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.8887
# Model| R2 sq on test set: 0.8528
# Model| MSE on test set: 0.1414
# Model| MAE on test set: 0.2811
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
knr1 = KNeighborsRegressor(n_neighbors = 4, weights = 'distance', algorithm = 'ball_tree')
knr1.fit(X_train, y_train)
model6 = knr1

# %%
print('Primero vemos las metricas')
abr_score = model6.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model6.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model6.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 1.0000
# Model| R2 sq on test set: 0.9102
# Model| MSE on test set: 0.0863
# Model| MAE on test set: 0.2089
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
par = GridSearchCV (PassiveAggressiveRegressor(),{'max_iter':[1000], 'random_state':[10], 'tol':[1e-10]},
                   cv=5,verbose = 3)
#loss = 'ls', este es least squares
par.fit(X_train, y_train) #Entrenamos el modelo
model7 = par.best_estimator_ #Nos quedamos con el mejor modelo
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END max_iter=1000, random_state=10, tol=1e-10;, score=0.802 total time=   0.0s
# [CV 2/5] END max_iter=1000, random_state=10, tol=1e-10;, score=0.860 total time=   0.0s
# [CV 3/5] END max_iter=1000, random_state=10, tol=1e-10;, score=0.508 total time=   0.0s
# [CV 4/5] END max_iter=1000, random_state=10, tol=1e-10;, score=0.709 total time=   0.0s
# [CV 5/5] END max_iter=1000, random_state=10, tol=1e-10;, score=0.796 total time=   0.0s

# %%
print('Primero vemos las metricas')
abr_score = model7.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model7.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model7.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.4057
# Model| R2 sq on test set: 0.4465
# Model| MSE on test set: 0.5315
# Model| MAE on test set: 0.6508
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
grid1 = GridSearchCV (RandomForestRegressor(),{'max_depth':[100], 'random_state':[0,1,2], 'criterion':['squared_error']
                                             }, cv=5, refit=True, verbose=3)
grid1.fit(X_train,y_train)
#Aqui lo que hacemos es quedarnos con el mejor metodo, el que da mejores resultados, lo llamamos en este caso: model1
model8 = grid1.best_estimator_
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END criterion=squared_error, max_depth=100, random_state=0;, score=0.949 total time=   0.8s
# [CV 2/5] END criterion=squared_error, max_depth=100, random_state=0;, score=0.926 total time=   0.8s
# [CV 3/5] END criterion=squared_error, max_depth=100, random_state=0;, score=0.925 total time=   0.8s
# [CV 4/5] END criterion=squared_error, max_depth=100, random_state=0;, score=0.892 total time=   0.8s
# [CV 5/5] END criterion=squared_error, max_depth=100, random_state=0;, score=0.933 total time=   0.9s
# [CV 1/5] END criterion=squared_error, max_depth=100, random_state=1;, score=0.950 total time=   0.8s
# [CV 2/5] END criterion=squared_error, max_depth=100, random_state=1;, score=0.926 total time=   0.8s
# [CV 3/5] END criterion=squared_error, max_depth=100, random_state=1;, score=0.931 total time=   0.8s
# [CV 4/5] END criterion=squared_error, max_depth=100, random_state=1;, score=0.895 total time=   0.8s
# [CV 5/5] END criterion=squared_error, max_depth=100, random_state=1;, score=0.925 total time=   0.8s
# [CV 1/5] END criterion=squared_error, max_depth=100, random_state=2;, score=0.948 total time=   0.8s
# [CV 2/5] END criterion=squared_error, max_depth=100, random_state=2;, score=0.926 total time=   0.7s
# [CV 3/5] END criterion=squared_error, max_depth=100, random_state=2;, score=0.926 total time=   0.8s
# [CV 4/5] END criterion=squared_error, max_depth=100, random_state=2;, score=0.890 total time=   0.8s
# [CV 5/5] END criterion=squared_error, max_depth=100, random_state=2;, score=0.924 total time=   0.8s

# %%
print('Primero vemos las metricas')
abr_score = model8.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model8.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model8.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.9915
# Model| R2 sq on test set: 0.9267
# Model| MSE on test set: 0.0704
# Model| MAE on test set: 0.1583
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sgd = (make_pipeline(StandardScaler(),SGDRegressor(max_iter=1000,tol=1e-1500,alpha=0.0001,epsilon=0.0001)))
sgd.fit(X_train, y_train) #Entrenamos el modelo
model9 = sgd #Nos quedamos con el mejor modelo

# %%
print('Primero vemos las metricas')
abr_score = model9.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model9.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model9.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.8559
# Model| R2 sq on test set: 0.8520
# Model| MSE on test set: 0.1421
# Model| MAE on test set: 0.2996
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
steps1 = [('scaler', StandardScaler()), ('SVM', SVR())]
pipeline1 = Pipeline(steps1) 
grid1 = GridSearchCV(pipeline1, param_grid= {'SVM__C':[100], 'SVM__gamma':['auto'], 'SVM__kernel': ['rbf'],
                                           'SVM__epsilon':[0.001]},cv = 5, refit=True,verbose=3, n_jobs = -1)
grid1.fit(X_train,y_train)
#Aqui lo que hacemos es quedarnos con el mejor metodo, el que da mejores resultados, lo llamamos en este caso: model1
model10 = grid1.best_estimator_
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits

# %%
print('Primero vemos las metricas')
abr_score = model10.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model10.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model10.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.9940
# Model| R2 sq on test set: 0.9382
# Model| MSE on test set: 0.0593
# Model| MAE on test set: 0.1295
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>
