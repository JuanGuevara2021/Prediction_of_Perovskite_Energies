# %%
import pandas as pd
import numpy as np
import time
import scipy.optimize as opt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
# %matplotlib inline 
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn import ensemble
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV 

from sklearn.ensemble import AdaBoostRegressor
from sklearn import linear_model
from sklearn.tree import DecisionTreeRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVR


from sklearn.gaussian_process.kernels import ConstantKernel, RBF
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve 
from sklearn.utils import shuffle

# %%
df = pd.read_csv('DatasetPerovskitasJuan.csv') #Aqui lo que se hace es cargar los datos.
df = df[df['Nsites'] == 5]
df = shuffle(df, random_state=2)
x = df.drop('Unnamed: 0', axis = 1)
x = x.drop('ID', axis = 1)
x = x.drop('full_formula', axis = 1)
x = x.drop('Energy', axis = 1)
x = x.drop('Energy_per_atom', axis = 1)
x = x.drop('Formation_energy_per_atom', axis = 1)
x = x.drop('E_above_hull', axis = 1)
x = x.drop("Band_gap",axis = 1) #Aqui quitamos la columna que correponde a la energia de gap
y = np.asarray(df['E_above_hull']) #Aqui definimos la cantidad que deseamos predecir, en este caso la energia de gap
x = (x-x.mean())/x.std()
y = (y-y.mean())/y.std()
x = x.fillna(0)

X_train, X_test, y_train, y_test = train_test_split( x, y, test_size=0.1, random_state=9)

# %%
plt.hist(y, bins = 50)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
abr1 = GridSearchCV (AdaBoostRegressor (),{
    'random_state':[0,1,2], 'n_estimators':[1000], 'learning_rate':[0.001], 'loss': ['exponential']}, cv=5)
abr1.fit(X_train, y_train)
model = abr1.best_estimator_

# %%
print('Primero vemos las metricas')
abr_score = model.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.5246
# Model| R2 sq on test set: 0.2617
# Model| MSE on test set: 0.5968
# Model| MAE on test set: 0.6072
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
BR = GridSearchCV (linear_model.BayesianRidge(),{'tol':[1e-3]}, cv=5)
BR.fit(X_train, y_train) #Entrenamos el modelo
model1 = BR.best_estimator_ #Nos quedamos con el mejor modelo

# %%
print('Primero vemos las metricas')
abr_score = model1.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model1.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model1.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.3938
# Model| R2 sq on test set: 0.1827
# Model| MSE on test set: 0.6607
# Model| MAE on test set: 0.6286
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dtr1 = GridSearchCV (DecisionTreeRegressor(),{
    'criterion':['friedman_mse'], 'random_state':[0,1,2], 'splitter':['best'], 'max_depth':[None]}, cv=5, verbose = 3)
dtr1.fit(X_train,y_train)
#Aqui lo que hacemos es quedarnos con el mejor metodo, el que da mejores resultados, lo llamamos en este caso: model1
model2 = dtr1.best_estimator_
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END criterion=friedman_mse, max_depth=None, random_state=0, splitter=best;, score=0.485 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, random_state=0, splitter=best;, score=0.561 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=None, random_state=0, splitter=best;, score=0.542 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=None, random_state=0, splitter=best;, score=0.356 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=None, random_state=0, splitter=best;, score=0.430 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=None, random_state=1, splitter=best;, score=0.468 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, random_state=1, splitter=best;, score=0.480 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=None, random_state=1, splitter=best;, score=0.514 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=None, random_state=1, splitter=best;, score=0.122 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=None, random_state=1, splitter=best;, score=0.459 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=None, random_state=2, splitter=best;, score=0.400 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=None, random_state=2, splitter=best;, score=0.521 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=None, random_state=2, splitter=best;, score=0.534 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=None, random_state=2, splitter=best;, score=0.197 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=None, random_state=2, splitter=best;, score=0.483 total time=   0.0s

# %%
print('Primero vemos las metricas')
abr_score = model2.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model2.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model2.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 1.0000
# Model| R2 sq on test set: 0.5032
# Model| MSE on test set: 0.4015
# Model| MAE on test set: 0.4298
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
kernel = 15*RBF(1.0)+10*RBF(2.0)+5*RBF(3.0) #Definimos que tipo de kernel usar, en este caso uno contante de 15 y 2 tipo RBF
gpr1 = make_pipeline(StandardScaler(), GaussianProcessRegressor(kernel = kernel))
gpr1.fit(X_train, y_train) #Entrenamos el modelo
model3 = gpr1

# %%
print('Primero vemos las metricas')
abr_score = model3.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model3.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model3.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 1.0000
# Model| R2 sq on test set: 0.4587
# Model| MSE on test set: 0.4375
# Model| MAE on test set: 0.4225
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
gbr = GridSearchCV(GradientBoostingRegressor (),{'n_estimators': [100,10,3], 'max_depth': [8], 'min_samples_split': [2], 'learning_rate': [0.1],
    'loss': ['squared_error'], 'random_state':[0,1,2]}, cv=5, verbose = 3)
#loss = 'ls', este es least squares
gbr.fit(X_train, y_train) #Entrenamos el modelo
model4 = gbr.best_estimator_ #Nos quedamos con el mejor modelo
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=0;, score=0.662 total time=   0.7s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=0;, score=0.725 total time=   0.7s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=0;, score=0.712 total time=   0.7s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=0;, score=0.534 total time=   0.7s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=0;, score=0.655 total time=   0.7s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=1;, score=0.649 total time=   0.7s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=1;, score=0.734 total time=   0.6s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=1;, score=0.705 total time=   0.6s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=1;, score=0.554 total time=   0.7s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=1;, score=0.651 total time=   0.7s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=2;, score=0.651 total time=   0.6s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=2;, score=0.740 total time=   0.6s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=2;, score=0.714 total time=   0.7s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=2;, score=0.536 total time=   0.7s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=100, random_state=2;, score=0.661 total time=   0.6s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=0;, score=0.541 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=0;, score=0.579 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=0;, score=0.583 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=0;, score=0.501 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=0;, score=0.560 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=1;, score=0.542 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=1;, score=0.585 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=1;, score=0.582 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=1;, score=0.509 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=1;, score=0.557 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=2;, score=0.535 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=2;, score=0.596 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=2;, score=0.589 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=2;, score=0.498 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=10, random_state=2;, score=0.559 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=0;, score=0.288 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=0;, score=0.276 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=0;, score=0.317 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=0;, score=0.302 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=0;, score=0.299 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=1;, score=0.294 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=1;, score=0.274 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=1;, score=0.323 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=1;, score=0.292 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=1;, score=0.290 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=2;, score=0.282 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=2;, score=0.298 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=2;, score=0.322 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=2;, score=0.308 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=squared_error, max_depth=8, min_samples_split=2, n_estimators=3, random_state=2;, score=0.292 total time=   0.0s

# %%
print('Primero vemos las metricas')
abr_score = model4.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model4.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model4.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.9997
# Model| R2 sq on test set: 0.5208
# Model| MSE on test set: 0.3874
# Model| MAE on test set: 0.3973
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
krr = GridSearchCV (KernelRidge (),{ 'alpha':[0.001],'kernel':['linear']}, cv=5,verbose=3)
krr.fit(X_train, y_train) #Entrenamos el modelo
model5 = krr.best_estimator_ #Nos quedamos con el mejor modelo
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ......alpha=0.001, kernel=linear;, score=-83.491 total time=   0.0s
# [CV 2/5] END ........alpha=0.001, kernel=linear;, score=0.380 total time=   0.0s
# [CV 3/5] END ........alpha=0.001, kernel=linear;, score=0.162 total time=   0.0s
# [CV 4/5] END ........alpha=0.001, kernel=linear;, score=0.222 total time=   0.0s
# [CV 5/5] END .......alpha=0.001, kernel=linear;, score=-0.345 total time=   0.0s

# %%
print('Primero vemos las metricas')
abr_score = model5.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model5.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model5.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.4064
# Model| R2 sq on test set: 0.1083
# Model| MSE on test set: 0.7208
# Model| MAE on test set: 0.6589
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
knr1 = KNeighborsRegressor(n_neighbors = 4, weights = 'distance', algorithm = 'ball_tree')
knr1.fit(X_train, y_train)
model6 = knr1

# %%
print('Primero vemos las metricas')
abr_score = model6.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model6.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model6.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 1.0000
# Model| R2 sq on test set: 0.4107
# Model| MSE on test set: 0.4763
# Model| MAE on test set: 0.4699
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
par = GridSearchCV (PassiveAggressiveRegressor(),{'max_iter':[1000], 'random_state':[10], 'tol':[1e-10]},
                   cv=5,verbose = 3)
#loss = 'ls', este es least squares
par.fit(X_train, y_train) #Entrenamos el modelo
model7 = par.best_estimator_ #Nos quedamos con el mejor modelo
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END max_iter=1000, random_state=10, tol=1e-10;, score=-0.904 total time=   0.0s
# [CV 2/5] END max_iter=1000, random_state=10, tol=1e-10;, score=-0.125 total time=   0.0s
# [CV 3/5] END max_iter=1000, random_state=10, tol=1e-10;, score=-0.390 total time=   0.0s
# [CV 4/5] END max_iter=1000, random_state=10, tol=1e-10;, score=-0.098 total time=   0.0s
# [CV 5/5] END max_iter=1000, random_state=10, tol=1e-10;, score=-0.055 total time=   0.0s

# %%
print('Primero vemos las metricas')
abr_score = model7.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model7.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model7.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: -0.2998
# Model| R2 sq on test set: -0.4592
# Model| MSE on test set: 1.1795
# Model| MAE on test set: 0.8462
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
grid1 = GridSearchCV (RandomForestRegressor(),{'max_depth':[100], 'random_state':[0,1,2], 'criterion':['squared_error']
                                             }, cv=5, refit=True, verbose=3)
grid1.fit(X_train,y_train)
#Aqui lo que hacemos es quedarnos con el mejor metodo, el que da mejores resultados, lo llamamos en este caso: model1
model8 = grid1.best_estimator_
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [CV 1/5] END criterion=squared_error, max_depth=100, random_state=0;, score=0.731 total time=   0.9s
# [CV 2/5] END criterion=squared_error, max_depth=100, random_state=0;, score=0.747 total time=   0.9s
# [CV 3/5] END criterion=squared_error, max_depth=100, random_state=0;, score=0.704 total time=   0.9s
# [CV 4/5] END criterion=squared_error, max_depth=100, random_state=0;, score=0.618 total time=   0.9s
# [CV 5/5] END criterion=squared_error, max_depth=100, random_state=0;, score=0.629 total time=   0.9s
# [CV 1/5] END criterion=squared_error, max_depth=100, random_state=1;, score=0.741 total time=   0.9s
# [CV 2/5] END criterion=squared_error, max_depth=100, random_state=1;, score=0.745 total time=   0.8s
# [CV 3/5] END criterion=squared_error, max_depth=100, random_state=1;, score=0.713 total time=   0.9s
# [CV 4/5] END criterion=squared_error, max_depth=100, random_state=1;, score=0.648 total time=   0.9s
# [CV 5/5] END criterion=squared_error, max_depth=100, random_state=1;, score=0.620 total time=   0.9s
# [CV 1/5] END criterion=squared_error, max_depth=100, random_state=2;, score=0.729 total time=   0.9s
# [CV 2/5] END criterion=squared_error, max_depth=100, random_state=2;, score=0.755 total time=   0.8s
# [CV 3/5] END criterion=squared_error, max_depth=100, random_state=2;, score=0.699 total time=   0.9s
# [CV 4/5] END criterion=squared_error, max_depth=100, random_state=2;, score=0.632 total time=   0.8s
# [CV 5/5] END criterion=squared_error, max_depth=100, random_state=2;, score=0.636 total time=   0.9s

# %%
print('Primero vemos las metricas')
abr_score = model8.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model8.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model8.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D')
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
#plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.9588
# Model| R2 sq on test set: 0.4445
# Model| MSE on test set: 0.4490
# Model| MAE on test set: 0.4418
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dif1 = (abs(yt - yp) / yt)*100
plt.hist(x=dif1, bins=50, color='#F2AB6D')
plt.title('Histograma del procentaje de error')
plt.xlabel('Porcentaje de error')
plt.ylabel('Frecuencia')
plt.xlim(-100,100)
plt.xticks(range(-100,101,10))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sgd = (make_pipeline(StandardScaler(),SGDRegressor(max_iter=1000,tol=1e-1500,alpha=0.0001,epsilon=0.0001)))
sgd.fit(X_train, y_train) #Entrenamos el modelo
model9 = sgd #Nos quedamos con el mejor modelo

# %%
print('Primero vemos las metricas')
abr_score = model9.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model9.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model9.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: -1302.8827
# Model| R2 sq on test set: -3.0298
# Model| MSE on test set: 3.2573
# Model| MAE on test set: 1.5384
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
steps1 = [('scaler', StandardScaler()), ('SVM', SVR())]
pipeline1 = Pipeline(steps1) 
grid1 = GridSearchCV(pipeline1, param_grid= {'SVM__C':[100], 'SVM__gamma':['auto'], 'SVM__kernel': ['rbf'],
                                           'SVM__epsilon':[0.001]},cv = 5, refit=True,verbose=3, n_jobs = -1)
grid1.fit(X_train,y_train)
#Aqui lo que hacemos es quedarnos con el mejor metodo, el que da mejores resultados, lo llamamos en este caso: model1
model10 = grid1.best_estimator_
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits

# %%
print('Primero vemos las metricas')
abr_score = model10.score(X_train,y_train) #Se evalua que tan bien entredo 
abr_score1 = model10.score(X_test,y_test) #Que tan bueno es en el conjunto de test
y_predicted = model10.predict(X_test) #Hacemos la inferencia con el conjunto test
yp = y_predicted# * sb + mb
yt = y_test #* sb + mb
print('Model| R2 sq on train set: %.4f'% abr_score)  #Mostramos las metricas que se obtuvieron.
print('Model| R2 sq on test set: %.4f'% abr_score1)
print('Model| MSE on test set: %.4f'% mean_squared_error(yt, yp))
print('Model| MAE on test set: %.4f'% mean_absolute_error(yt, yp))   

print('Ahora lo que vemos son la diferencia entre el valor real y el predicho')
dif = yp-yt
plt.hist(x=dif, bins=25, color='#F2AB6D', rwidth=0.85, density = True)
plt.title('Histograma de Diferencia entre el valor real y predicho')
plt.xlabel('Diferencia')
plt.ylabel('Frecuencia')
plt.xticks(range(-3,4))
plt.show
# Out:
# Primero vemos las metricas
# Model| R2 sq on train set: 0.7944
# Model| R2 sq on test set: 0.5490
# Model| MSE on test set: 0.3645
# Model| MAE on test set: 0.4181
# Ahora lo que vemos son la diferencia entre el valor real y el predicho
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print('Lo que vemos es el valor predicho y el real')
plt.plot(yt,yp,'o')
plt.plot(y_test,y_test,'o')
plt.grid()
plt.show
# Out:
# Lo que vemos es el valor predicho y el real
# <function matplotlib.pyplot.show(close=None, block=None)>
